# %%
import pandas as pd
import numpy as np

# %%
file_input = 'dados_treated/Braga_2010_24h.csv'

# %%
df = pd.read_csv(file_input, encoding = 'latin-1')

# %%
print(df)
# Out:
#             Concelho          Datahora     M     FG                      Via  \
# 0             Amares  2010-03-04 18:30   0.0    1.0                  EN205-3
# 1             Amares  2010-06-02 14:00   0.0    1.0                    EN308
# 2             Amares  2010-06-28 12:30   0.0    1.0             R DE CINTURA
# 3             Amares  2010-07-02 17:25   0.0    1.0                    EN205
# 4             Amares  2010-07-14 09:25   0.0    1.0                    EN205
# 5             Amares  2010-08-07 00:30   0.0    1.0                    EN308
# 6             Amares  2010-08-14 07:15   0.0    1.0              AV DO MONTE
# 7             Amares  2010-08-23 15:40   0.0    1.0                    EN308
# 8             Amares  2010-10-28 18:30   0.0    1.0           R S PEDRO FINS
# 9             Amares  2010-11-11 16:15   1.0    0.0              R DE PASSOS
# 10            Amares  2010-11-21 02:30   0.0    1.0             R DA CINTURA
# ...
